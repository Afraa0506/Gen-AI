# %%
# !pip install transformers torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 41.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 52.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from transformers import MarianMTModel, MarianTokenizer

model_name = 'Helsinki-NLP/opus-mt-en-de'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
text = "Hello, how are you?"

tokenized_text = tokenizer.encode(text, return_tensors="pt")

translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# Original Text: Hello, how are you?
# Translated Text: Hallo, wie geht's?

# %%
# Load the pre-trained MarianMT model and tokenizer for English to Portuguese translation
model_name = 'Helsinki-NLP/opus-mt-en-ru'  # English to Portuguese model
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/307M [00:00<?, ?B/s]
# Error during conversion: ChunkedEncodingError(ProtocolError('Response ended prematurely'))
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/307M [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
text = "Hello, how are you?"

tokenized_text = tokenizer.encode(text, return_tensors="pt")

translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# Original Text: Hello, how are you?
# Translated Text: Привет, как дела?

# %%
# Load the pre-trained MarianMT model and tokenizer for English to Turkish translation
model_name = 'Helsinki-NLP/opus-mt-en-fr'  # English to Turkish model
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Example text to translate
text = "Hello, how are you?"

# Tokenize the text
tokenized_text = tokenizer.encode(text, return_tensors="pt")

# Translate the text
translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

# Decode the translated text
translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

# Display the original and translated text
print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# Original Text: Hello, how are you?
# Translated Text: Bonjour, comment ça va ?

# %%
model_name = 'Helsinki-NLP/opus-mt-en-it'  # English to Turkish model
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Example text to translate
text = "Hello, how are you?"

# Tokenize the text
tokenized_text = tokenizer.encode(text, return_tensors="pt")

# Translate the text
translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

# Decode the translated text
translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

# Display the original and translated text
print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/343M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/789k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# Original Text: Hello, how are you?
# Translated Text: Salve, come va?

# %%
model_name = 'Helsinki-NLP/opus-mt-en-nl'  # English to Turkish model
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Example text to translate
text = "Hello, how are you?"

# Tokenize the text
tokenized_text = tokenizer.encode(text, return_tensors="pt")

# Translate the text
translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

# Decode the translated text
translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

# Display the original and translated text
print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/316M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/316M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/790k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.66M [00:00<?, ?B/s]
# Original Text: Hello, how are you?
# Translated Text: Hallo, hoe gaat het?

# %%
model_name = 'Helsinki-NLP/opus-mt-en-zh'  # English to Turkish model
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Example text to translate
text = "Hello, how are you?"

# Tokenize the text
tokenized_text = tokenizer.encode(text, return_tensors="pt")

# Translate the text
translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

# Decode the translated text
translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

# Display the original and translated text
print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/806k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# Original Text: Hello, how are you?
# Translated Text: 你好,你好吗?

# %%
model_name = 'Helsinki-NLP/opus-mt-en-ar'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Example text to translate
text = "Hello, how are you?"

# Tokenize the text
tokenized_text = tokenizer.encode(text, return_tensors="pt")

# Translate the text
translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

# Decode the translated text
translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

# Display the original and translated text
print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/801k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/917k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# Original Text: Hello, how are you?
# Translated Text: مرحبا، كيف حالك؟

# %%
model_name = 'Helsinki-NLP/opus-mt-en-hi'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Example text to translate
text = "Hello, how are you?"

# Tokenize the text
tokenized_text = tokenizer.encode(text, return_tensors="pt")

# Translate the text
translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

# Decode the translated text
translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

# Display the original and translated text
print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/306M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# Original Text: Hello, how are you?
# Translated Text: हैलो, तुम कैसे हो?

# %%
model_name = 'Helsinki-NLP/opus-mt-en-vi'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Example text to translate
text = "Hello, how are you?"

# Tokenize the text
tokenized_text = tokenizer.encode(text, return_tensors="pt")

# Translate the text
translated = model.generate(tokenized_text, max_length=40, num_beams=4, early_stopping=True)

# Decode the translated text
translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

# Display the original and translated text
print(f"Original Text: {text}")
print(f"Translated Text: {translated_text}")
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/289M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/289M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/809k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/756k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.19M [00:00<?, ?B/s]
# Original Text: Hello, how are you?
# Translated Text: Xin chào, anh khỏe không?

# %%
# !pip install tensorflow tensorflow-tts
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement tensorflow-tts (from versions: none)
# ERROR: No matching distribution found for tensorflow-tts

# %%
# !pip install gTTS

# %%
from gtts import gTTS

# %%
import os

text = "Hello, how are you today? I hope you have a great day!"
language = 'de'

speech = gTTS(text=text, lang=language, slow=False)
speech.save("output.mp3")

from IPython.display import Audio
Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
